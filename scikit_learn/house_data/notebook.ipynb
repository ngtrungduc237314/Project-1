# %% [markdown]
# Dataset sử dụng: https://www.kaggle.com/datasets/ashydv/housing-dataset/data
#
# a) Nếu xây dựng mô hình hồi quy tuyến tính dự đoán giá nhà chỉ phụ thuộc chỉ phụ thuộc vào 1 biến (ví dụ là diện tích) thì phần khai phá, tiền xử lý dữ liệu được bỏ qua và khi đánh giá, các sai số lần lượt là MAE: 1,057,024.82,
#
# MSE: 2,087,288,517,330.23,
#
# R²: 0.324
#
# Đánh giá:
# R² ≈ 0.324: khả năng giải thích dữ liệu còn hạn chế.
#
# MAE ≈ 1.05 triệu: mức độ sai lệch trung bình còn tương đối lớn so với giá trị thực tế.
#
# b) Điều này cho thấy diện tích không phải là yếu tố duy nhất quyết định giá nhà, và cần bổ sung thêm các biến khác để cải thiện mô hình.
